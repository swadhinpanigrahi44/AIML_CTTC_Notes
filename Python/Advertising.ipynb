# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the Dataset
adv = pd.read_csv(r"C:\Users\ASUS\Desktop\aiml\advertising.csv")
adv
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#Data cleaning
adv.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
adv.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
adv.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
for i in adv.columns:
    print(i,':','\n',adv[i].unique(),'\n')
# Out:
# TV :
#  [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7  53.5
#  261.3 239.3 102.7 131.1  69.   31.5 139.3 216.8 199.1 109.8  26.8 129.4
#  213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4 213.5 193.2
#   76.3 110.7  88.3 134.3  28.6 217.7 250.9 107.4 163.3 197.6 184.9 289.7
#  135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4  13.1 255.4 225.8
#  241.7 175.7 209.6  78.2  75.1 139.2 125.7  19.4 141.3  18.8 224.  123.1
#  229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2   8.4 219.8  36.9  48.3
#   25.6 273.7  43.   73.4 193.7 220.5 104.6  96.2 140.3 243.2  38.   44.7
#  280.7 121.  171.3 187.8   4.1  93.9 149.8  11.7 131.7 172.5  85.7 188.4
# ...

# %%
d=adv.describe(include='all')
d
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
adv.columns = ['TV', 'Radio', 'Newspaper', 'Sales']
adv.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Distribution Plot
sns.distplot(adv.TV)
plt.show()

# %%
sns.histplot(adv.TV)
plt.show()

# %%
sns.displot(adv.TV)
plt.show()

# %%
sns.kdeplot(adv.TV)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#ip/op creation
ip=adv.drop('Sales',axis=1)
op=adv.Sales

# %%
ip.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
op.head()
# Out:
# 0    22.1
# 1    10.4
# 2    12.0
# 3    16.5
# 4    17.9
# Name: Sales, dtype: float64

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.2, random_state=2000)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 126    7.8   38.9       50.6
# 17   281.4   39.6       55.8
# 87   110.7   40.6       63.2
# 175  276.9   48.9       41.8
# 82    75.3   20.3       32.5
# ..     ...    ...        ...
# 28   248.8   27.1       22.9
# 123  123.1   34.6       12.4
# 54   262.7   28.8       15.9
# 72    26.8   33.0       19.3
# 182   56.2    5.7       29.7
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 47   239.9   41.5       18.5
# 140   73.4   17.0       12.9
# 139  184.9   43.9        1.7
# 25   262.9    3.5       19.5
# 113  209.6   20.6       10.7
# 19   147.3   23.9       19.1
# 176  248.4   30.2       20.3
# 3    151.5   41.3       58.5
# 179  165.6   10.0       17.6
# 115   75.1   35.0       52.7
# 77   120.5   28.5       14.2
# 38    43.1   26.7       35.1
# 181  218.5    5.4       27.4
# 84   213.5   43.0       33.8
# 94   107.4   14.0       10.9
# 136   25.6   39.0        9.3
# 73   129.4    5.7       31.3
# 86    76.3   27.5       16.0
# 66    31.5   24.6        2.2
# 68   237.4   27.5       11.0
# 138   43.0   25.9       20.5
# 59   210.7   29.5        9.3
# 104  238.2   34.3        5.3
# 88    88.3   25.5       73.4
# 95   163.3   31.6       52.9
# 56     7.3   28.1       41.4
# 192   17.2    4.1       31.6
# 65    69.0    9.3        0.9
# 50   199.8    3.1       34.6
# 185  205.0   45.1       19.6
# 155    4.1   11.6        5.7
# ...

# %%
y_train
# Out:
# 126     6.6
# 17     24.4
# 87     16.0
# 175    27.0
# 82     11.3
#        ...
# 28     18.9
# 123    15.2
# 54     20.2
# 72      8.8
# 182     8.7
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 47     23.2
# 140    10.9
# 139    20.7
# 25     17.0
# 113    20.9
# 19     14.6
# 176    20.2
# 3      16.5
# 179    17.6
# 115    12.6
# 77     14.2
# 38     10.1
# 181    17.2
# 84     21.7
# 94     11.5
# 136     9.5
# 73     11.0
# 86     12.0
# 66     11.0
# 68     18.9
# 138     9.6
# 59     18.4
# 104    20.7
# 88     12.9
# 95     16.9
# 56      5.5
# 192     5.9
# 65     11.3
# 50     16.4
# 185    22.6
# 155     3.2
# 2      12.0
# 187    17.3
# 67     13.4
# 61     24.2
# 135    11.6
# 163    18.0
# 0      22.1
# 27     20.9
# 159    12.9
# Name: Sales, dtype: float64

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 3)
# (40, 3)
# (160,)
# (40,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-1.62602456e+00,  1.08121696e+00,  8.51035963e-01],
#        [ 1.53332827e+00,  1.12749698e+00,  1.08720618e+00],
#        [-4.37803047e-01,  1.19361129e+00,  1.42329456e+00],
#        [ 1.48136523e+00,  1.74236009e+00,  4.51363292e-01],
#        [-8.46578962e-01, -1.48509277e-01,  2.89819458e-02],
#        [ 5.82982007e-01,  5.32468154e-01,  3.10569510e-01],
#        [ 1.05642304e+00, -1.00799536e+00, -1.05195096e+00],
#        [ 3.12774199e-01, -4.72469414e-01, -1.33808026e+00],
#        [ 9.64044301e-01, -9.22046747e-01, -1.05195096e+00],
#        [ 1.83443966e-01, -1.08840689e-01,  7.05700446e-01],
#        [ 1.44441374e+00,  4.20073821e-01,  1.26433384e+00],
#        [-5.90227964e-01, -9.88161061e-01, -1.12007698e+00],
#        [-8.13091669e-01,  1.60352004e+00,  1.19816644e-01],
#        [-8.33876885e-01,  2.74622330e-01, -4.34275014e-01],
#        [ 8.52035081e-01, -1.26584118e+00, -8.52114625e-01],
#        [-1.56482365e+00, -1.46418412e+00, -2.84397762e-01],
# ...

# %%
# Machine Learning Model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Prediction
pred = lr.predict(x_test)
pred
# Out:
# array([22.64886624, 10.13548719, 19.74900632, 19.43218212, 18.39765847,
#        15.21958303, 21.78988546, 17.59396317, 14.60916752, 12.43829837,
#        14.22097691,  9.58175101, 17.11582675, 21.33019746, 11.73012539,
#        10.00996834, 12.03146326, 11.56129697,  8.61889535, 20.82183989,
#         9.46060128, 19.52261655, 21.67275375, 12.09041672, 17.105988  ,
#         7.69819214,  5.38632896,  8.94593183, 15.77500851, 21.07293698,
#         5.49390661, 10.43267594, 18.3115852 , 13.62398422, 24.07239087,
#        12.27073298, 17.67722082, 21.71169571, 19.70265767, 13.68593605])

# %%
y_test
# Out:
# 47     23.2
# 140    10.9
# 139    20.7
# 25     17.0
# 113    20.9
# 19     14.6
# 176    20.2
# 3      16.5
# 179    17.6
# 115    12.6
# 77     14.2
# 38     10.1
# 181    17.2
# 84     21.7
# 94     11.5
# 136     9.5
# 73     11.0
# 86     12.0
# 66     11.0
# 68     18.9
# 138     9.6
# 59     18.4
# 104    20.7
# 88     12.9
# 95     16.9
# 56      5.5
# 192     5.9
# 65     11.3
# 50     16.4
# 185    22.6
# 155     3.2
# 2      12.0
# 187    17.3
# 67     13.4
# 61     24.2
# 135    11.6
# 163    18.0
# 0      22.1
# 27     20.9
# 159    12.9
# Name: Sales, dtype: float64

# %%
#Accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(pred,y_test)
r2 = r2_score(pred,y_test)

print('Mean Squared Error : ',mse)
print('R2 Score : ',r2)
# Out:
# Mean Squared Error :  1.656079020882368
# R2 Score :  0.9349684831384614

# %%
# Linear Model Plot
df = pd.DataFrame({'Y_Test':list(y_test),'Prediction':pred})
df
# Out:
#     Y_Test  Prediction
# 0     23.2   22.648866
# 1     10.9   10.135487
# 2     20.7   19.749006
# 3     17.0   19.432182
# 4     20.9   18.397658
# 5     14.6   15.219583
# 6     20.2   21.789885
# 7     16.5   17.593963
# 8     17.6   14.609168
# 9     12.6   12.438298
# 10    14.2   14.220977
# 11    10.1    9.581751
# 12    17.2   17.115827
# 13    21.7   21.330197
# 14    11.5   11.730125
# 15     9.5   10.009968
# 16    11.0   12.031463
# 17    12.0   11.561297
# 18    11.0    8.618895
# 19    18.9   20.821840
# 20     9.6    9.460601
# 21    18.4   19.522617
# 22    20.7   21.672754
# 23    12.9   12.090417
# 24    16.9   17.105988
# 25     5.5    7.698192
# 26     5.9    5.386329
# 27    11.3    8.945932
# 28    16.4   15.775009
# 29    22.6   21.072937
# 30     3.2    5.493907
# 31    12.0   10.432676
# 32    17.3   18.311585
# 33    13.4   13.623984
# 34    24.2   24.072391
# 35    11.6   12.270733
# 36    18.0   17.677221
# 37    22.1   21.711696
# 38    20.9   19.702658
# ...

# %%
sns.lmplot(x='Y_Test', y='Prediction', data=df)
plt.show()
