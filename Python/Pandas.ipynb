# %% [markdown]
# ### <font color='red'>Pandas</font>: pandas is an open source python library designed for data manipulation and analysis .it provides powerful and flexible data structures, in form of series and DataFrame.

# %%
import pandas as pd
import numpy as np

# %%
# Yanhan se baki sab NOTE me likha hua hai

# %%
#dataframe
d={'name':['vishnu','ram','sita','hari','krishna','radhey'],'Roll':[21,22,23,24,26,27],'age':[23,24,19,22,20,21]}
d
# Out:
# {'name': ['vishnu', 'ram', 'sita', 'hari', 'krishna', 'radhey'],
#  'Roll': [21, 22, 23, 24, 26, 27],
#  'age': [23, 24, 19, 22, 20, 21]}

# %%
#dictionary to DataFrame
df= pd.DataFrame(d)
df
# Out:
#       name  Roll  age
# 0   vishnu    21   23
# 1      ram    22   24
# 2     sita    23   19
# 3     hari    24   22
# 4  krishna    26   20
# 5   radhey    27   21

# %%
df.head()
# Out:
#       name  Roll  age
# 0   vishnu    21   23
# 1      ram    22   24
# 2     sita    23   19
# 3     hari    24   22
# 4  krishna    26   20

# %%
df.head(2) ## df(n)-print the n number of rows of the data frame from the beginning
# Out:
#      name  Roll  age
# 0  vishnu    21   23
# 1     ram    22   24

# %%
df.tail() #By deafult niche se 5 rows ko print karta hai
# Out:
#       name  Roll  age
# 1      ram    22   24
# 2     sita    23   19
# 3     hari    24   22
# 4  krishna    26   20
# 5   radhey    27   21

# %%
df.tail(3)
# Out:
#       name  Roll  age
# 3     hari    24   22
# 4  krishna    26   20
# 5   radhey    27   21

# %%
#rename
df = df.rename(columns={'name':'Student_Name'})
df
# Out:
#   Student_Name  Roll  age
# 0       vishnu    21   23
# 1          ram    22   24
# 2         sita    23   19
# 3         hari    24   22
# 4      krishna    26   20
# 5       radhey    27   21

# %%
df.Student_Name[4]
# Out:
# 'krishna'

# %%
#set index
df.set_index('Roll')
# Out:
#      Student_Name  age
# Roll
# 21         vishnu   23
# 22            ram   24
# 23           sita   19
# 24           hari   22
# 26        krishna   20
# 27         radhey   21

# %%
#df.set_index('Roll',inplace=True)
#df

# %%
d = pd.DataFrame({'Days':[1,2,3,4,5,6],'Places':['kendrapada','bhadrak','nayagarh',np.NaN,'konark','puri'],'visiters':[100,4000,5000,10,5000,9900000]})
d
# Out:
#    Days      Places  visiters
# 0     1  kendrapada       100
# 1     2     bhadrak      4000
# 2     3    nayagarh      5000
# 3     4         NaN        10
# 4     5      konark      5000
# 5     6        puri   9900000

# %%
#check missing values
d.isnull()
# Out:
#     Days  Places  visiters
# 0  False   False     False
# 1  False   False     False
# 2  False   False     False
# 3  False    True     False
# 4  False   False     False
# 5  False   False     False

# %%
d.isnull().sum()
# Out:
# Days        0
# Places      1
# visiters    0
# dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Days      6 non-null      int64
#  1   Places    5 non-null      object
#  2   visiters  6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 276.0+ bytes

# %%
#fillna
d.Places.fillna('koraput',inplace=True)
d
# Out:
#    Days      Places  visiters
# 0     1  kendrapada       100
# 1     2     bhadrak      4000
# 2     3    nayagarh      5000
# 3     4     koraput        10
# 4     5      konark      5000
# 5     6        puri   9900000

# %%
#d=d.replace(np.NaN,'Puri')  --- ye ak alag tarika hai 
#d

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
d.visiters.replace(10,5555,inplace=True)
d
# Out:
#    Days      Places  visiters
# 0     1  kendrapada       100
# 1     2     bhadrak      4000
# 2     3    nayagarh      5000
# 3     4     koraput      5555
# 4     5      konark      5000
# 5     6        puri   9900000

# %%
d.Places.unique()
# Out:
# array(['kendrapada', 'bhadrak', 'nayagarh', 'koraput', 'konark', 'puri'],
#       dtype=object)

# %%
d.visiters.mean()
# Out:
# 1653275.8333333333

# %%
d.max()
# Out:
# Days              6
# Places         puri
# visiters    9900000
# dtype: object

# %%
d.describe()
# Out:
#            Days      visiters
# count  6.000000  6.000000e+00
# mean   3.500000  1.653276e+06
# std    1.870829  4.040054e+06
# min    1.000000  1.000000e+02
# 25%    2.250000  4.250000e+03
# 50%    3.500000  5.000000e+03
# 75%    4.750000  5.416250e+03
# max    6.000000  9.900000e+06

# %%
d.describe(include='all')
# Out:
#             Days      Places      visiters
# count   6.000000           6  6.000000e+00
# unique       NaN           6           NaN
# top          NaN  kendrapada           NaN
# freq         NaN           1           NaN
# mean    3.500000         NaN  1.653276e+06
# std     1.870829         NaN  4.040054e+06
# min     1.000000         NaN  1.000000e+02
# 25%     2.250000         NaN  4.250000e+03
# 50%     3.500000         NaN  5.000000e+03
# 75%     4.750000         NaN  5.416250e+03
# max     6.000000         NaN  9.900000e+06

# %%
d.describe(include='O')
# Out:
#             Places
# count            6
# unique           6
# top     kendrapada
# freq             1

# %%
#To download pre-built free databases
#1. uci machine learning repository
#2. kaggle
