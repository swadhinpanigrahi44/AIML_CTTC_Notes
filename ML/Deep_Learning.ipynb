# %% [markdown]
# ## Deep Learning:

# %% [markdown]
# #### Deeplearning is a subset of mechine learning which uses nural network.It is inspired from the structure and functionof the nural network of human brain..
# #### It can work on huge amount of data it can solve complex problems and can automatically extracts features and patterns from the data..
# #### In machine learning training is fast and testing is comparatively slow ,where as in deep learning training is very slow and testing is very fast..
# ## Activation Function:
# ##### IT decides whether the neural should be activated or not while calculating the weighted of and further adding the biased value....

# %% [markdown]
# ### ANN(Artificial Neuran Network):
# #### It has three layer *input layer
# ####                     *hidden layer
# ####                     *output layer

# %% [markdown]
# ##### Different types of activation function

# %%
linear
sigmoid
TanH-Hyperbolic Tangent
ReLU(both for continious and discontinious)-Rectified Linear Unit
