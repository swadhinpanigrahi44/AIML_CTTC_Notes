# %% [markdown]
# # <font color='red'>Machine Learning</font>

# %% [markdown]
# ### <font color='red'>ML</font> IS OF 3 TYPES:
# <ul>
#     <li><font color='red'>Supervise</font></li>
#     <li><font color='red'>Unsupervise</font></li>
#     <li><font color='red'>Reinforcement</font></li>
# </ul>

# %% [markdown]
# ### Supervise is of 2 Types:
# <ul>
#     <li>Regression ML(O/P-Continuous)</li>
#     <li>Classification ML(O/P-Category)</li>
# </ul>
#
# #### Regression ML is of 4 Types:
# <ol>
#     <li>Linear Regression</li>
#     <li>Polynomial Regression</li>
#     <li>Lasso Regression</li>
#     <li>Ridge Regression</li>
# </ol>
#
# #### Classification ML is of 4 Types:
# <ol>
#     <li>Logistic regression</li>
#     <li>Naive Bayes</li>
#     <li>K-nearest neighbors (KNN)</li>
#     <li>Support vector machine (SVM)</li>
# </ol>

# %% [markdown]
# ## Steps for ML model
# <ol>
#     <li>Reading Dataset</li>
#     <li>Cleaning Dataset</li>
#     <li>Data analysis/Visualize</li>
#     <li>Encoding</li>
#     <li>INPUT/OUTPUT Creation</li>
#     <li>Train-Test-Split</li>
#     <li>Standard Scaler Transform</li>
#     <li>Read Machine Learning Model</li>
#     <li>Prediction</li>
#     <li>Accuracy</li>
# </ol>

# %% [markdown]
# # Label Encoding
# <ol>
#     <li>One Hot Encoding</li>
#     <li>Dummy Encoding</li>
#     <li>Target Encoding</li>
#     <li>Ordinal Encoding</li>
#     <li>Frequency Encoding</li>
# </ol>

# %% [markdown]
# ### Unsupervise is of 2 Types:
# <ol>
#     <li>Clustering</li>
#     <li>Dimensionality reduction</li>
# </ol>
#
# #### Clustering is of 4 Types:
# <ol>
#     <li>K Mean clustering</li>
#     <li>Agglomaratve clustering</li>
#     <li>Hierarchial clustering</li>
#     <li>Fuzzy clustering</li>
# </ol>
#
# #### Dimensionality reduction is of 2 Types:
# <ol>
#     <li>PCA - principal component analysys</li>
#     <li>LDA - linear discrimitive analysis</li>
# </ol>

# %% [markdown]
# ### K Mean clustering

# %% [markdown]
# # NLP - Natural Language Processing
# ## natural language - human understanding language
# ## processing - It processes the human understanding language to computer understanding language(binary code)
# ### EX- both audio and text
# ### eg voice-alexa,siri, google assistant
# ### eg text- chatgpt, Google keyboard
#
#
# # NLU- NATURAL LANGUAGE UNDERSTANDING, NLU INTERPRETS THE USER INPUT. THEN THE SYSTEM DECIDES WHAT TO RESPOND
# # NLG- NATURAL LANGUAGE GENERATION, NLG GENERATES THE TEXTUAL RESPONSE
#
#
# #### BASIC TERMINOLOGY IN NLP:
# 1. CORPUS = A LARGE AND STRUCTURED SET OF TEXT USED FOR NLP/LINGUISTIC RESEARCH
# 2. DOCUMENT = IT IS NOTHING BUT A TOKEN OF A SENTENCE/ A SINGLE SENTENCE OR WORDS
# 3. VOCABULARY
# 4. VECTOR
# 5. STOP WORDS
# 6. TOKENS
#
# #### STEPS FOR NLP:
# 1. TOKENIZATION
# 2. STEMMING
# 3. LEMMATIZATION
# 4. POStags - Parts of speech
# 5. NAMED ENTITY RECOGNITION
# 6. CHUNKING
#
# ##### TOKENIZATION:
